# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
User_input = input("Enter your Institue Name? :")
# Out:
# Enter your Institue Name? : Hope AI

# %%
Name = input("Enter your name : ")
Age = int(input("Enter your Age : "))
School = input("Enter your School : ")
Degree = input("Enter your Degree : ")
# Out:
# Enter your name :  Raj
# Enter your Age :  15
# Enter your School :  Guru School
# Enter your Degree :  B.E. CSE

# %%
a = int(input("a="))
b = int(input('b='))
Add = a+b
print('Add=', Add)
# Out:
# a= 43
# b= 34
# Add= 77

# %%
sub = a-b
print('sub=',sub)
# Out:
# sub= 9

# %%
a = int(input("a="))
b = int(input('b='))
Mul = a+b
print('Mul=', Mul)
# Out:
# a= 63
# b= 97
# Mul= 160

# %%
a = int(input("a="))
b = int(input('b='))
Div = float (a/b)
print('Div=', Div)
# Out:
# a= 76
# b= 31
# Div= 2.4516129032258065

# %%
a = int(input("a="))
b = int(input('b='))
Floor_Div = float (a//b)
print('Floor_Div', Floor_Div)
# Out:
# a= 76
# b= 31
# Floor_Div 2.0

# %%
Modulo = a%b
print('Modulo=', Modulo)
# Out:
# Modulo= 14

# %%
a = int(input("a="))
b = int(input('b='))
Power = a**b
print('Power=', Power)
# Out:
# a= 4
# b= 4
# Power= 256
