# %%
var = int(input('Input a number : '))
if var == 10:
    print ('Correct')
else:
    Print ('Wrong')
# Out:
# Input a number :  10
# Correct

# %%
var = int(input('Input a number : '))
if var == 10:
    print ('Correct')
else:
    print ('Wrong')
# Out:
# Input a number :  11
# Wrong

# %%
var = int(input('Input a number : '))
if var == 10:
    print ('Correct')
else:
    print ('Wrong')
# Out:
# Input a number :  9
# Wrong

# %%
Input_String = input('Enter the Password')
if Input_String == ('HOPE@123'):
    print ('Your Password is correct')
else:
    print('Your Password is incorrect')
# Out:
# Enter the Password HOPE@123
# Your Password is correct

# %%
Input_String = input('Enter the Password')
if Input_String == ('HOPE@123'):
    print ('Your Password is correct')
else:
    print('Your Password is incorrect')
# Out:
# Enter the Password H0PE@123
# Your Password is incorrect

# %%
Input_String = input('Enter the Password')
if Input_String == 'HOPE@123':
    print ('Your Password is correct')
else:
    print('Your Password is incorrect')
# Out:
# Enter the Password HOPE@123
# Your Password is correct

# %%
Input_Age = int(input('Enter your Age :'))
if Input_Age <= 17:
    print ('You are a Child')
elif Input_Age >= 18 and Input_Age <= 50:
    print ('You are a Adult')
elif Input_Age >= 51 and Input_Age <= 70:
    print ('You are a Citizen')
else:
    print ('You are a Senior Citizen')
# Out:
# Enter your Age : 18
# You are a Adult

# %%
Input_Age = int(input('Enter your Age :'))
if Input_Age <= 17:
    print ('You are a Child')
elif Input_Age >= 18 and Input_Age <= 50:
    print ('You are a Adult')
elif Input_Age >= 51 and Input_Age <= 70:
    print ('You are a Citizen')
else:
    print ('You are a Senior Citizen')
# Out:
# Enter your Age : 15
# You are a Child

# %%
Input_Age = int(input('Enter your Age :'))
if Input_Age <= 17:
    print ('You are a Child')
elif Input_Age >= 18 and Input_Age <= 50:
    print ('You are a Adult')
elif Input_Age >= 51 and Input_Age <= 70:
    print ('You are a Citizen')
else:
    print ('You are a Senior Citizen')
# Out:
# Enter your Age : 80
# You are a Senior Citizen

# %%
Input_Age = int(input('Enter your Age :'))
if Input_Age <= 17:
    print ('You are a Child')
elif Input_Age >= 18 and Input_Age <= 50:
    print ('You are a Adult')
elif Input_Age >= 51 and Input_Age <= 70:
    print ('You are a Citizen')
else:
    print ('You are a Senior Citizen')
# Out:
# Enter your Age : 50
# You are a Adult

# %%
Input_Age = int(input('Enter your Age :'))
if Input_Age <= 17:
    print ('You are a Child')
elif Input_Age >= 18 and Input_Age <= 50:
    print ('You are a Adult')
elif Input_Age >= 51 and Input_Age <= 70:
    print ('You are a Citizen')
else:
    print ('You are a Senior Citizen')
# Out:
# Enter your Age : 69
# You are a Citizen

# %%
num = int (input ('Enter an (+) or (-) Number : '))
if num >= 0:
    print ('the number you entered : ',num,'is a Positive number')
else:
    print ('the number you entered : ',num,'is a Negative number')
# Out:
# Enter an (+) or (-) Number :  0
# the number you entered :  0 is a Positive number

# %%
num = int (input ('Enter an (+) or (-) Number : '))
if num >= 0:
    print ('the number you entered : ',num,'is a Positive number')
else:
    print ('the number you entered : ',num,'is a Negative number')
# Out:
# Enter an (+) or (-) Number :  10
# the number you entered :  10 is a Positive number

# %%
num = int (input ('Enter an (+) or (-) Number : '))
if num >= 0:
    print ('the number you entered : ',num,'is a Positive number')
else:
    print ('the number you entered : ',num,'is a Negative number')
# Out:
# Enter an (+) or (-) Number :  -0
# the number you entered :  0 is a Positive number

# %%
num = int (input ('Enter an (+) or (-) Number : '))
if num >= 0:
    print ('the number you entered : ',num,'is a Positive number')
else:
    print ('the number you entered : ',num,'is a Negative number')
# Out:
# Enter an (+) or (-) Number :  -1
# the number you entered :  -1 is a Negative number

# %%
num = int (input ('Enter an (+) or (-) Number : '))
if num >= 0:
    print ('the number you entered : ',num,'is a Positive number')
else:
    print ('the number you entered : ',num,'is a Negative number')
# Out:
# Enter an (+) or (-) Number :  #
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 num = int (input ('Enter an (+) or (-) Number : '))
#       2 if num >= 0:
#       3     print ('the number you entered : ',num,'is a Positive number')
#       4 else:
#
# ValueError: invalid literal for int() with base 10: '#'

# %%
num = int (input ('Enter a number : '))
if num % 5 == 0:
    print ('The number', num , 'is divisible by 5')
else:
    print ('The number', num , "is not divisible by 5")
# Out:
# Enter a number :  22
# The number 22 is not divisible by 5

# %%
num = int (input ('Enter a number : '))
if num % 5 == 0:
    print ('The number', num , 'is divisible by 5')
else:
    print ('The number', num , "is not divisible by 5")
# Out:
# Enter a number :  10
# The number 10 is divisible by 5

# %%
num = int (input ('Enter a number : '))
if num % 5 == 0:
    print ('The number', num , 'is divisible by 5')
else:
    print ('The number', num , "is not divisible by 5")
# Out:
# Enter a number :  3
# The number 3 is not divisible by 5

# %%
num = int (input ('Enter a number : '))
if num % 5 == 0:
    print ('The number', num , 'is divisible by 5')
else:
    print ('The number', num , "is not divisible by 5")
# Out:
# Enter a number :  1234567000
# The number 1234567000 is divisible by 5

# %%
num = int (input ('Enter a number : '))
if num % 5 == 0:
    print ('The number', num , 'is divisible by 5')
else:
    print ('The number', num , "is not divisible by 5")
# Out:
# Enter a number :  -50
# The number -50 is divisible by 5
