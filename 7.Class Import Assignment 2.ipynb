# %%
from MainClass import ClassFirst

# %%
ClassFirst.Subfields()
# Out:
# Sub-Fields in a Functions are :
# Machin Learning
# Neural Network
# Vision
# Robotics
# Speech Processing
# Natural Languag Processing

# %%
ClassFirst.oddEven()
# Out:
# Enter an number 23
# 23 is odd number

# %%
ClassFirst.Bridedetails()
# Out:
# Enter your Gender : male
# Enter your Age :  20
# NOT ELIGIBLE

# %%
ClassFirst.Marks()
# Out:
# Subject 1: Enter the Mark:  98
# Subject 2: Enter the Mark:  87
# Subject 3: Enter the Mark:  95
# Subject 4: Enter the Mark:  95
# Subject 5: Enter the Mark:  93
# 468

# %%
ClassFirst.Areatriange()
# Out:
# Height :  32
# Breadth :  34
# 544.0

# %%
ClassFirst.Perimeter()
# Out:
# Height 1 :  2
# Height 2 :  4
# Breadth :  4
# 10
